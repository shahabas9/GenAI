# %%
# !pip install datasets sentence_transformers pymongo pinecone langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.6/587.6 kB 43.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 79.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.0/240.0 kB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 132.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 104.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...

# %%
# !pip install -U fsspec datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 19.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.7.0
#     Uninstalling fsspec-2025.7.0:
#       Successfully uninstalled fsspec-2025.7.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# ...

# %%
from pymongo import MongoClient
from bson import json_util
import os
from datasets import load_dataset

# Paste your URI here (be careful not to share this!)
uri = "mongodb+srv://mohdshahabasm:XKqhPbjSTJL2lipx@cluster0.9mfxz3h.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0&tlsAllowInvalidCertificates=true"

client = MongoClient(uri)
db_name = 'sample_mflix'
collection_name = 'embedded_movies'

embedded_movies_collection = client[db_name][collection_name]

# Try loading a specific revision of the dataset
dataset = load_dataset("MongoDB/embedded_movies")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# sample_mflix.embedded_movies.json:   0%|          | 0.00/42.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1500 [00:00<?, ? examples/s]

# %%
import pandas as pd
data=pd.DataFrame(dataset["train"])

# %%
data=data.dropna(subset=["fullplot"])

# %%
data=data.drop(columns=["plot_embedding"])

# %%
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("thenlper/gte-large")
# Out:
# modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://mohdshahabasm:XKqhPbjSTJL2lipx@cluster0.9mfxz3h.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db=client["moviemydb"]

# %%
collection=db["moviemycollection"]

# %%
document=data.to_dict("records")

# %%
collection.insert_many(document)
# Out:
# InsertManyResult([ObjectId('687b68bfddf50742c6c95609'), ObjectId('687b68bfddf50742c6c9560a'), ObjectId('687b68bfddf50742c6c9560b'), ObjectId('687b68bfddf50742c6c9560c'), ObjectId('687b68bfddf50742c6c9560d'), ObjectId('687b68bfddf50742c6c9560e'), ObjectId('687b68bfddf50742c6c9560f'), ObjectId('687b68bfddf50742c6c95610'), ObjectId('687b68bfddf50742c6c95611'), ObjectId('687b68bfddf50742c6c95612'), ObjectId('687b68bfddf50742c6c95613'), ObjectId('687b68bfddf50742c6c95614'), ObjectId('687b68bfddf50742c6c95615'), ObjectId('687b68bfddf50742c6c95616'), ObjectId('687b68bfddf50742c6c95617'), ObjectId('687b68bfddf50742c6c95618'), ObjectId('687b68bfddf50742c6c95619'), ObjectId('687b68bfddf50742c6c9561a'), ObjectId('687b68bfddf50742c6c9561b'), ObjectId('687b68bfddf50742c6c9561c'), ObjectId('687b68bfddf50742c6c9561d'), ObjectId('687b68bfddf50742c6c9561e'), ObjectId('687b68bfddf50742c6c9561f'), ObjectId('687b68bfddf50742c6c95620'), ObjectId('687b68bfddf50742c6c95621'), ObjectId('687b68bfddf50742c6c9
# ...

# %%
PINECONE_API_KEY = "pcsk_68kcYw_JDSVfoRk5UDoXrzNMKnBGNWqd61voYF7GBsFMfhZkRMyhc4U63fCTHhJS2NbfJ1"

# %%
from pinecone import Pinecone

pc = Pinecone(api_key=PINECONE_API_KEY)
index = pc.Index("mongomovies")
print(index)

# %%
def get_result(query,similar_result=3):
  embedding=embedding_model.encode(query)
  embedding=embedding.tolist()

  result=index.query(
    vector=embedding,
    top_k=similar_result,
  )
  return result

# %%
query="what is the best horror movie to watch and why?"

# %%
result=get_result(query)

# %%
result
# Out:
# {'matches': [{'id': '687b68bfddf50742c6c9573e',
#               'score': 0.787974834,
#               'values': []},
#              {'id': '687b68bfddf50742c6c9576d',
#               'score': 0.772374213,
#               'values': []},
#              {'id': '687b68bfddf50742c6c956bd',
#               'score': 0.77061528,
#               'values': []}],
#  'namespace': '',
#  'usage': {}}

# %%
from bson.objectid import ObjectId

# %%
mylist=[]
for i in  range(len(result["matches"])):
  value=result["matches"][i]['id']
  mylist.append(collection.find_one({"_id": ObjectId(value)}))

# %%
mylist
# Out:
# [{'_id': ObjectId('687b68bfddf50742c6c9573e'),
#   'plot': 'A tough-on-crime street cop must protect the only surviving witness to a strange murderous cult with far reaching plans.',
#   'runtime': 87.0,
#   'genres': ['Action', 'Crime', 'Thriller'],
# ...

# %%
combined_information = ""
for i in range(len(mylist)):
  fullplot=mylist[i]["fullplot"]
  title=mylist[i]["title"]
  combined_information += f"Title:{title}, fullplot: {fullplot}\n"

# %%
print(combined_information)
# Out:
# Title:Cobra, fullplot: A gang of neo-fascist thugs, led by the self-proclaimed 'Night Slasher', are breaking into people's homes & cars, then killing them at random. When of of these thugs holds up a food store & takes hostages, Lt. Marian Cobretti - an intense, take-no-prisoners cop, is brought onto the scene to end the hostage-taking. Ranting bizarrely about a 'New World', the man levels a sawed-off shotgun at Cobretti, who hits him with a knife, then guns him down when the man refuses to put down his weapon. Later that night, another murder occurs, attributed to the Night Slasher - and the next day, another one. This one is witnessed by a young woman, Ingrid Knutsen. She drives away before the thugs can kill her, but it isn't long before some creepy-looking people start making attempts on her life - and Cobretti's. Cobretti plans to move the only witness to the blood spree upstate, but with inside information, the thugs follow them. And a battle for survival rages between Cobretti
# ...

# %%
prompt = f"Query: {query}\nContinue to answer the query by using the fullplot only:\n{combined_information}."

# %%
print(prompt)
# Out:
# Query: what is the best horror movie to watch and why?
# Continue to answer the query by using the fullplot only:
# ...

# %%
import os
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
def load_model(model_name):
  if model_name=="gemini-1.5-pro-latest":
    llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest")
  else:
    llm=ChatGoogleGenerativeAI(model="gemini-pro-vision")

  return llm

# %%
model_text=load_model("gemini-1.5-pro-latest")

# %%
model_text.invoke(prompt).content
# Out:
# 'There\'s no single "best" horror movie as taste is subjective. However, based purely on the provided fullplots and focusing on horror elements:\n\n* **_Cobra_** presents a slasher-style horror with a neo-fascist gang terrorizing people.  The plot focuses on escalating violence and survival, creating a sense of dread and suspense.  While it has action elements, the random killings and the threat to both Cobretti and Ingrid contribute to a horror atmosphere.\n\n* **_The Monster Squad_** leans more towards horror-comedy or adventure with horror elements.  The inclusion of classic Universal monsters like Dracula creates a recognizable horror setting, but the focus on kids fighting back suggests a lighter tone than a purely horror film.\n\n* **_Mad Max_**, while containing violence and a dystopian setting, is primarily an action film with post-apocalyptic elements. The horror comes from the societal breakdown and Max\'s descent into madness, but the core plot revolves around revenge and 
# ...
